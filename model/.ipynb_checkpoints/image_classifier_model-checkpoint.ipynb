# %%
import numpy as np
'''import cv2'''
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import cv2
import pywt

# %%
import sys
# !{sys.executable} -m pip install opencv-python

# %%
img = cv2.imread('./dataset/sundar/sundar.jpg')

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
(x,y,w,h) = faces[0]
x,y,w,h

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".jpg"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1

# %%
def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'elon': ['./dataset/cropped/elon\\elon1.jpg',
#   './dataset/cropped/elon\\elon10.jpg',
#   './dataset/cropped/elon\\elon11.jpg',
#   './dataset/cropped/elon\\elon12.jpg',
#   './dataset/cropped/elon\\elon13.jpg',
#   './dataset/cropped/elon\\elon14.jpg',
#   './dataset/cropped/elon\\elon15.jpg',
#   './dataset/cropped/elon\\elon16.jpg',
#   './dataset/cropped/elon\\elon17.jpg',
#   './dataset/cropped/elon\\elon18.jpg',
#   './dataset/cropped/elon\\elon19.jpg',
#   './dataset/cropped/elon\\elon2.jpg',
#   './dataset/cropped/elon\\elon20.jpg',
#   './dataset/cropped/elon\\elon21.jpg',
#   './dataset/cropped/elon\\elon22.jpg',
#   './dataset/cropped/elon\\elon23.jpg',
#   './dataset/cropped/elon\\elon24.jpg',
#   './dataset/cropped/elon\\elon25.jpg',
#   './dataset/cropped/elon\\elon26.jpg',
#   './dataset/cropped/elon\\elon27.jpg',
#   './dataset/cropped/elon\\elon28.jpg',
#   './dataset/cropped/elon\\elon29.jpg',
#   './dataset/cropped/elon\\elon3.jpg',
#   './dataset/cropped/elon\\elon30.jpg',
#   './dataset/cropped/elon\\elon31.jpg',
#   './dataset/cropped/elon\\elon32.jpg',
#   './dataset/cropped/elon\\elon33.jpg',
#   './dataset/cropped/elon\\elon34.jpg',
#   './dataset/cropped/elon\\elon35.jpg',
#   './dataset/cropped/elon\\elon36.jpg',
#   './dataset/cropped/elon\\elon37.jpg',
#   './dataset/cropped/elon\\elon38.jpg',
#   './dataset/cropped/elon\\elon39.jpg',
#   './dataset/cropped/elon\\elon4.jpg',
#   './dataset/cropped/elon\\elon40.jpg',
#   './dataset/cropped/elon\\elon41.jpg',
#   './dataset/cropped/elon\\elon42.jpg',
#   './dataset/cropped/elon\\elon43.jpg',
#   './dataset/cropped/elon\\elon44.jpg',
#   './dataset/cropped/elon\\elon45.jpg',
#   './dataset/cropped/elon\\elon46.jpg',
#   './dataset/cropped/elon\\elon5.jpg',
#   './dataset/cropped/elon\\elon6.jpg',
#   './dataset/cropped/elon\\elon7.jpg',
#   './dataset/cropped/elon\\elon8.jpg',
#   './dataset/cropped/elon\\elon9.jpg'],
#  'kohli': ['./dataset/cropped/kohli\\kohli1.jpg',
#   './dataset/cropped/kohli\\kohli10.jpg',
#   './dataset/cropped/kohli\\kohli11.jpg',
#   './dataset/cropped/kohli\\kohli12.jpg',
#   './dataset/cropped/kohli\\kohli13.jpg',
#   './dataset/cropped/kohli\\kohli14.jpg',
#   './dataset/cropped/kohli\\kohli15.jpg',
#   './dataset/cropped/kohli\\kohli16.jpg',
#   './dataset/cropped/kohli\\kohli17.jpg',
#   './dataset/cropped/kohli\\kohli18.jpg',
#   './dataset/cropped/kohli\\kohli19.jpg',
#   './dataset/cropped/kohli\\kohli2.jpg',
#   './dataset/cropped/kohli\\kohli20.jpg',
#   './dataset/cropped/kohli\\kohli21.jpg',
#   './dataset/cropped/kohli\\kohli22.jpg',
#   './dataset/cropped/kohli\\kohli23.jpg',
#   './dataset/cropped/kohli\\kohli24.jpg',
#   './dataset/cropped/kohli\\kohli25.jpg',
#   './dataset/cropped/kohli\\kohli26.jpg',
#   './dataset/cropped/kohli\\kohli27.jpg',
#   './dataset/cropped/kohli\\kohli28.jpg',
#   './dataset/cropped/kohli\\kohli29.jpg',
#   './dataset/cropped/kohli\\kohli3.jpg',
#   './dataset/cropped/kohli\\kohli30.jpg',
#   './dataset/cropped/kohli\\kohli31.jpg',
#   './dataset/cropped/kohli\\kohli32.jpg',
#   './dataset/cropped/kohli\\kohli33.jpg',
#   './dataset/cropped/kohli\\kohli4.jpg',
#   './dataset/cropped/kohli\\kohli5.jpg',
#   './dataset/cropped/kohli\\kohli6.jpg',
#   './dataset/cropped/kohli\\kohli7.jpg',
#   './dataset/cropped/kohli\\kohli8.jpg',
#   './dataset/cropped/kohli\\kohli9.jpg'],
#  'priyanka': ['./dataset/cropped/priyanka\\priyanka1.jpg',
#   './dataset/cropped/priyanka\\priyanka10.jpg',
#   './dataset/cropped/priyanka\\priyanka11.jpg',
#   './dataset/cropped/priyanka\\priyanka12.jpg',
#   './dataset/cropped/priyanka\\priyanka13.jpg',
#   './dataset/cropped/priyanka\\priyanka14.jpg',
#   './dataset/cropped/priyanka\\priyanka15.jpg',
#   './dataset/cropped/priyanka\\priyanka16.jpg',
#   './dataset/cropped/priyanka\\priyanka17.jpg',
#   './dataset/cropped/priyanka\\priyanka18.jpg',
#   './dataset/cropped/priyanka\\priyanka19.jpg',
#   './dataset/cropped/priyanka\\priyanka2.jpg',
#   './dataset/cropped/priyanka\\priyanka20.jpg',
#   './dataset/cropped/priyanka\\priyanka21.jpg',
#   './dataset/cropped/priyanka\\priyanka22.jpg',
#   './dataset/cropped/priyanka\\priyanka23.jpg',
#   './dataset/cropped/priyanka\\priyanka24.jpg',
#   './dataset/cropped/priyanka\\priyanka25.jpg',
#   './dataset/cropped/priyanka\\priyanka26.jpg',
#   './dataset/cropped/priyanka\\priyanka27.jpg',
#   './dataset/cropped/priyanka\\priyanka28.jpg',
#   './dataset/cropped/priyanka\\priyanka29.jpg',
#   './dataset/cropped/priyanka\\priyanka3.jpg',
#   './dataset/cropped/priyanka\\priyanka30.jpg',
#   './dataset/cropped/priyanka\\priyanka31.jpg',
#   './dataset/cropped/priyanka\\priyanka32.jpg',
#   './dataset/cropped/priyanka\\priyanka33.jpg',
#   './dataset/cropped/priyanka\\priyanka34.jpg',
#   './dataset/cropped/priyanka\\priyanka35.jpg',
#   './dataset/cropped/priyanka\\priyanka36.jpg',
#   './dataset/cropped/priyanka\\priyanka37.jpg',
#   './dataset/cropped/priyanka\\priyanka38.jpg',
#   './dataset/cropped/priyanka\\priyanka39.jpg',
#   './dataset/cropped/priyanka\\priyanka4.jpg',
#   './dataset/cropped/priyanka\\priyanka40.jpg',
#   './dataset/cropped/priyanka\\priyanka41.jpg',
#   './dataset/cropped/priyanka\\priyanka42.jpg',
#   './dataset/cropped/priyanka\\priyanka43.jpg',
#   './dataset/cropped/priyanka\\priyanka44.jpg',
#   './dataset/cropped/priyanka\\priyanka45.jpg',
#   './dataset/cropped/priyanka\\priyanka46.jpg',
#   './dataset/cropped/priyanka\\priyanka47.jpg',
#   './dataset/cropped/priyanka\\priyanka5.jpg',
#   './dataset/cropped/priyanka\\priyanka6.jpg',
#   './dataset/cropped/priyanka\\priyanka7.jpg',
#   './dataset/cropped/priyanka\\priyanka8.jpg',
#   './dataset/cropped/priyanka\\priyanka9.jpg'],
#  'rock': ['./dataset/cropped/rock\\rock1.jpg',
#   './dataset/cropped/rock\\rock10.jpg',
#   './dataset/cropped/rock\\rock11.jpg',
#   './dataset/cropped/rock\\rock12.jpg',
#   './dataset/cropped/rock\\rock13.jpg',
#   './dataset/cropped/rock\\rock14.jpg',
#   './dataset/cropped/rock\\rock15.jpg',
#   './dataset/cropped/rock\\rock16.jpg',
#   './dataset/cropped/rock\\rock17.jpg',
#   './dataset/cropped/rock\\rock18.jpg',
#   './dataset/cropped/rock\\rock19.jpg',
#   './dataset/cropped/rock\\rock2.jpg',
#   './dataset/cropped/rock\\rock20.jpg',
#   './dataset/cropped/rock\\rock21.jpg',
#   './dataset/cropped/rock\\rock22.jpg',
#   './dataset/cropped/rock\\rock23.jpg',
#   './dataset/cropped/rock\\rock24.jpg',
#   './dataset/cropped/rock\\rock25.jpg',
#   './dataset/cropped/rock\\rock26.jpg',
#   './dataset/cropped/rock\\rock27.jpg',
#   './dataset/cropped/rock\\rock28.jpg',
#   './dataset/cropped/rock\\rock29.jpg',
#   './dataset/cropped/rock\\rock3.jpg',
#   './dataset/cropped/rock\\rock4.jpg',
#   './dataset/cropped/rock\\rock5.jpg',
#   './dataset/cropped/rock\\rock6.jpg',
#   './dataset/cropped/rock\\rock7.jpg',
#   './dataset/cropped/rock\\rock8.jpg',
#   './dataset/cropped/rock\\rock9.jpg'],
#  'ronaldo': ['./dataset/cropped/ronaldo\\ronaldo1.jpg',
#   './dataset/cropped/ronaldo\\ronaldo10.jpg',
#   './dataset/cropped/ronaldo\\ronaldo11.jpg',
#   './dataset/cropped/ronaldo\\ronaldo12.jpg',
#   './dataset/cropped/ronaldo\\ronaldo13.jpg',
#   './dataset/cropped/ronaldo\\ronaldo14.jpg',
#   './dataset/cropped/ronaldo\\ronaldo15.jpg',
#   './dataset/cropped/ronaldo\\ronaldo16.jpg',
#   './dataset/cropped/ronaldo\\ronaldo17.jpg',
#   './dataset/cropped/ronaldo\\ronaldo18.jpg',
#   './dataset/cropped/ronaldo\\ronaldo19.jpg',
#   './dataset/cropped/ronaldo\\ronaldo2.jpg',
#   './dataset/cropped/ronaldo\\ronaldo20.jpg',
#   './dataset/cropped/ronaldo\\ronaldo21.jpg',
#   './dataset/cropped/ronaldo\\ronaldo22.jpg',
#   './dataset/cropped/ronaldo\\ronaldo23.jpg',
#   './dataset/cropped/ronaldo\\ronaldo24.jpg',
#   './dataset/cropped/ronaldo\\ronaldo25.jpg',
#   './dataset/cropped/ronaldo\\ronaldo26.jpg',
#   './dataset/cropped/ronaldo\\ronaldo27.jpg',
#   './dataset/cropped/ronaldo\\ronaldo28.jpg',
#   './dataset/cropped/ronaldo\\ronaldo29.jpg',
#   './dataset/cropped/ronaldo\\ronaldo3.jpg',
#   './dataset/cropped/ronaldo\\ronaldo30.jpg',
#   './dataset/cropped/ronaldo\\ronaldo31.jpg',
#   './dataset/cropped/ronaldo\\ronaldo32.jpg',
#   './dataset/cropped/ronaldo\\ronaldo33.jpg',
#   './dataset/cropped/ronaldo\\ronaldo34.jpg',
#   './dataset/cropped/ronaldo\\ronaldo35.jpg',
#   './dataset/cropped/ronaldo\\ronaldo36.jpg',
#   './dataset/cropped/ronaldo\\ronaldo37.jpg',
#   './dataset/cropped/ronaldo\\ronaldo38.jpg',
#   './dataset/cropped/ronaldo\\ronaldo39.jpg',
#   './dataset/cropped/ronaldo\\ronaldo4.jpg',
#   './dataset/cropped/ronaldo\\ronaldo40.jpg',
#   './dataset/cropped/ronaldo\\ronaldo5.jpg',
#   './dataset/cropped/ronaldo\\ronaldo6.jpg',
#   './dataset/cropped/ronaldo\\ronaldo7.jpg',
#   './dataset/cropped/ronaldo\\ronaldo8.jpg',
#   './dataset/cropped/ronaldo\\ronaldo9.jpg'],
#  'satya': ['./dataset/cropped/satya\\satya1.jpg',
#   './dataset/cropped/satya\\satya10.jpg',
#   './dataset/cropped/satya\\satya11.jpg',
#   './dataset/cropped/satya\\satya12.jpg',
#   './dataset/cropped/satya\\satya2.jpg',
#   './dataset/cropped/satya\\satya3.jpg',
#   './dataset/cropped/satya\\satya4.jpg',
#   './dataset/cropped/satya\\satya5.jpg',
#   './dataset/cropped/satya\\satya6.jpg',
#   './dataset/cropped/satya\\satya7.jpg',
#   './dataset/cropped/satya\\satya8.jpg',
#   './dataset/cropped/satya\\satya9.jpg'],
#  'steve': ['./dataset/cropped/steve\\steve1.jpg',
#   './dataset/cropped/steve\\steve10.jpg',
#   './dataset/cropped/steve\\steve11.jpg',
#   './dataset/cropped/steve\\steve12.jpg',
#   './dataset/cropped/steve\\steve13.jpg',
#   './dataset/cropped/steve\\steve2.jpg',
#   './dataset/cropped/steve\\steve3.jpg',
#   './dataset/cropped/steve\\steve4.jpg',
#   './dataset/cropped/steve\\steve5.jpg',
#   './dataset/cropped/steve\\steve6.jpg',
#   './dataset/cropped/steve\\steve7.jpg',
#   './dataset/cropped/steve\\steve8.jpg',
#   './dataset/cropped/steve\\steve9.jpg'],
#  'sundar': ['./dataset/cropped/sundar\\sundar1.jpg',
#   './dataset/cropped/sundar\\sundar10.jpg',
#   './dataset/cropped/sundar\\sundar11.jpg',
#   './dataset/cropped/sundar\\sundar12.jpg',
#   './dataset/cropped/sundar\\sundar13.jpg',
#   './dataset/cropped/sundar\\sundar14.jpg',
#   './dataset/cropped/sundar\\sundar15.jpg',
#   './dataset/cropped/sundar\\sundar16.jpg',
#   './dataset/cropped/sundar\\sundar17.jpg',
#   './dataset/cropped/sundar\\sundar18.jpg',
#   './dataset/cropped/sundar\\sundar19.jpg',
#   './dataset/cropped/sundar\\sundar2.jpg',
#   './dataset/cropped/sundar\\sundar20.jpg',
#   './dataset/cropped/sundar\\sundar3.jpg',
#   './dataset/cropped/sundar\\sundar4.jpg',
#   './dataset/cropped/sundar\\sundar5.jpg',
#   './dataset/cropped/sundar\\sundar6.jpg',
#   './dataset/cropped/sundar\\sundar7.jpg',
#   './dataset/cropped/sundar\\sundar8.jpg',
#   './dataset/cropped/sundar\\sundar9.jpg'],
#  'zuck': ['./dataset/cropped/zuck\\zuck1.jpg',
#   './dataset/cropped/zuck\\zuck10.jpg',
#   './dataset/cropped/zuck\\zuck11.jpg',
#   './dataset/cropped/zuck\\zuck12.jpg',
#   './dataset/cropped/zuck\\zuck13.jpg',
#   './dataset/cropped/zuck\\zuck14.jpg',
#   './dataset/cropped/zuck\\zuck15.jpg',
#   './dataset/cropped/zuck\\zuck16.jpg',
#   './dataset/cropped/zuck\\zuck17.jpg',
#   './dataset/cropped/zuck\\zuck18.jpg',
#   './dataset/cropped/zuck\\zuck19.jpg',
#   './dataset/cropped/zuck\\zuck2.jpg',
#   './dataset/cropped/zuck\\zuck20.jpg',
#   './dataset/cropped/zuck\\zuck21.jpg',
#   './dataset/cropped/zuck\\zuck22.jpg',
#   './dataset/cropped/zuck\\zuck23.jpg',
#   './dataset/cropped/zuck\\zuck24.jpg',
#   './dataset/cropped/zuck\\zuck25.jpg',
#   './dataset/cropped/zuck\\zuck26.jpg',
#   './dataset/cropped/zuck\\zuck27.jpg',
#   './dataset/cropped/zuck\\zuck28.jpg',
#   './dataset/cropped/zuck\\zuck29.jpg',
#   './dataset/cropped/zuck\\zuck3.jpg',
#   './dataset/cropped/zuck\\zuck30.jpg',
#   './dataset/cropped/zuck\\zuck31.jpg',
#   './dataset/cropped/zuck\\zuck32.jpg',
#   './dataset/cropped/zuck\\zuck33.jpg',
#   './dataset/cropped/zuck\\zuck34.jpg',
#   './dataset/cropped/zuck\\zuck35.jpg',
#   './dataset/cropped/zuck\\zuck4.jpg',
#   './dataset/cropped/zuck\\zuck5.jpg',
#   './dataset/cropped/zuck\\zuck6.jpg',
#   './dataset/cropped/zuck\\zuck7.jpg',
#   './dataset/cropped/zuck\\zuck8.jpg',
#   './dataset/cropped/zuck\\zuck9.jpg'],
#  'z_alia': ['./dataset/cropped/z_alia\\z_alia1.jpg',
#   './dataset/cropped/z_alia\\z_alia10.jpg',
#   './dataset/cropped/z_alia\\z_alia11.jpg',
#   './dataset/cropped/z_alia\\z_alia12.jpg',
#   './dataset/cropped/z_alia\\z_alia13.jpg',
#   './dataset/cropped/z_alia\\z_alia14.jpg',
#   './dataset/cropped/z_alia\\z_alia15.jpg',
#   './dataset/cropped/z_alia\\z_alia16.jpg',
#   './dataset/cropped/z_alia\\z_alia17.jpg',
#   './dataset/cropped/z_alia\\z_alia18.jpg',
#   './dataset/cropped/z_alia\\z_alia19.jpg',
#   './dataset/cropped/z_alia\\z_alia2.jpg',
#   './dataset/cropped/z_alia\\z_alia20.jpg',
#   './dataset/cropped/z_alia\\z_alia21.jpg',
#   './dataset/cropped/z_alia\\z_alia22.jpg',
#   './dataset/cropped/z_alia\\z_alia23.jpg',
#   './dataset/cropped/z_alia\\z_alia24.jpg',
#   './dataset/cropped/z_alia\\z_alia25.jpg',
#   './dataset/cropped/z_alia\\z_alia26.jpg',
#   './dataset/cropped/z_alia\\z_alia27.jpg',
#   './dataset/cropped/z_alia\\z_alia28.jpg',
#   './dataset/cropped/z_alia\\z_alia29.jpg',
#   './dataset/cropped/z_alia\\z_alia3.jpg',
#   './dataset/cropped/z_alia\\z_alia30.jpg',
#   './dataset/cropped/z_alia\\z_alia31.jpg',
#   './dataset/cropped/z_alia\\z_alia32.jpg',
#   './dataset/cropped/z_alia\\z_alia33.jpg',
#   './dataset/cropped/z_alia\\z_alia34.jpg',
#   './dataset/cropped/z_alia\\z_alia4.jpg',
#   './dataset/cropped/z_alia\\z_alia5.jpg',
#   './dataset/cropped/z_alia\\z_alia6.jpg',
#   './dataset/cropped/z_alia\\z_alia7.jpg',
#   './dataset/cropped/z_alia\\z_alia8.jpg',
#   './dataset/cropped/z_alia\\z_alia9.jpg']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'elon': 0,
#  'kohli': 1,
#  'priyanka': 2,
#  'rock': 3,
#  'ronaldo': 4,
#  'satya': 5,
#  'steve': 6,
#  'sundar': 7,
#  'zuck': 8,
#  'z_alia': 9}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (309, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df

# %%
best_estimators
